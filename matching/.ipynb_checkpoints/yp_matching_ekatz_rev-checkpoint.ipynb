# %% [markdown]
# # Задача матчинга

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# ## Описание проекта
#
# В нашем распоряжении датасеты с полностью анонимизированными признаками. Задача заключается в том чтобы соотнести запросы из train и validation датасетов с объектами из base на основании их схожести и найти 5 наиболее близких объекта к каждому запросу.
#
# <b>Описание данных</b>
#
# В ходе проекта мы пройдём следующие этапы:
#
# * загрузка и ознакомление с данными
# * предобработка данных
# * выбор лучшей модели матчинга
# * получение предсказаний на валидационной выборке
# * итоговая оценка качества лучшей модели

# %% [markdown]
# ## Загрузка данных.

# %% [markdown]
# Загрузим данные и посмотрим общую информацию о них.

# %%
import pandas as pd

import numpy as np
from numpy.random import RandomState

import sklearn
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import NearestNeighbors

import statistics as st
import math

import matplotlib.pyplot as plt
import seaborn as sns

import warnings
import time

import faiss
# Out:
# C:\Users\Katya\AppData\Roaming\Python\Python311\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
def load_data(path, kind='mini'):
    if kind=='test':
        try:
            base = pd.read_csv(path + 'base_mini.csv', index_col = 0)
            train = pd.read_csv(path + 'train_mini.csv', index_col = 0)
            validation = pd.read_csv(path + 'validation_mini.csv', index_col = 0)
            validation_answer = pd.read_csv(path + 'validation_answer_mini.csv', index_col = 0)
        except FileNotFoundError:
            print('Данные не найдены')
    else:
        try:
            base = pd.read_csv(path + 'base.csv', index_col = 0)
            train = pd.read_csv(path + 'train.csv', index_col = 0)
            validation = pd.read_csv(path + 'validation.csv', index_col = 0)
            validation_answer = pd.read_csv(path + 'validation_answer.csv', index_col = 0)
        except FileNotFoundError:
            print('Данные не найдены')
    return base, train, validation, validation_answer

# %%
def describe_data(data):
    display(data.head())
    display(data.info())
    print('Описание')
    display(data.describe)

# %% [markdown]
# #### Загрузка mini датасетов

# %% [markdown]
# Загрузим также мини наборы данных для более быстрых тестов.

# %%
path = 'C:/Users/Katya/Desktop/ds_learning/18sprint_masterskaya_2/matching/'

# %%
base, train, validation, validation_answer = load_data(path, 'mini')

# %%
describe_data(base)
# Out:
#                   0          1           2          3          4          5  \
# Id
# 6-base  -132.349780  12.640369  -80.635895 -137.11795  89.345490 -94.853520
# 10-base  -98.898865   5.633918  -88.647285 -158.90100  87.810620 -76.610000
# 12-base  -68.859090  -0.939237  -47.824863 -153.82768  89.371060 -83.141740
# 13-base  -71.780470   9.491869  -80.955360 -105.35263  84.318450 -78.632150
# 14-base -121.066216   6.920069 -134.866850 -132.77559  19.703812 -37.102016
#
#                   6           7           8          9  ...         62  \
# Id                                                      ...
# 6-base  -462.934000   91.356030  126.557274  147.39490  ... -55.650047
# 10-base    6.748629  -27.250978  126.672390  120.37991  ... -81.505670
# 12-base -529.278500   39.693317  118.244225  140.70552  ... -58.820076
# 13-base -429.259030  108.983040  124.514730  138.17792  ... -29.982979
# 14-base   83.941820  -78.876540  125.779030   86.25271  ... -64.943320
#
#                 63         64          65        66         67          68  \
# Id
# 6-base   29.008305 -138.24612  156.300500  67.05420 -25.324776   85.734146
# 10-base  19.662066 -125.73326   18.915530  67.41328  48.166084  146.343660
# 12-base  76.393720 -180.40990   85.385710  67.94069 -20.363410  162.172640
# 99990-query  50.564724 -229.965060  -23.577913  65.918846  18.661448
# 99991-query  -0.923378 -119.212685  -82.762085  70.363235  22.567661
# 99995-query  38.573555 -133.087130   14.040794  66.477340 -36.148730
#
#                      68          69          70          71        Target
# Id
# 1-query       89.974976  130.589630 -1035.09220  -51.276833   366656-base
# 14-query      91.174060   86.220680  -951.97925 -119.347946    88328-base
# 17-query      31.847046  125.621956 -1179.73110  -48.768707  1841709-base
# 21-query      53.082397  113.545525  -653.41100    8.083492     9331-base
# 24-query      57.041412  141.719480 -1181.58060  -36.334442   915740-base
# ...                 ...         ...         ...         ...           ...
# 99984-query   81.697190  131.575740  -598.80023  -31.511417   282254-base
# 99989-query  120.186844  131.445980 -1074.46480  -57.181810   635083-base
# 99990-query   17.368996   93.971550    -0.95380  -73.878000   616075-base
# 99991-query   22.723671  109.992630 -1239.75880  -58.607340    22985-base
# 99995-query   61.689774  107.037950 -1074.46480  -35.128250   811868-base
#
# [20000 rows x 73 columns]>

# %%
describe_data(validation)
# Out:
#                       0         1          2          3           4  \
# Id
# 100004-query  -79.53292 -0.364173 -16.027431 -170.88495  165.453920
# 100005-query  -89.74536  6.317698 -80.744650 -114.53197  153.960340
# 100007-query -119.02685  7.536469 -62.973827 -142.94609  150.376110
# 100010-query  -57.71042  5.344710 -36.634872 -151.92635  123.258860
# 100013-query -113.83982  5.682194  -7.384804 -142.80922   63.082832
#
#                       5           6          7           8           9  ...  \
# Id                                                                      ...
# 100004-query -28.291668   33.931934  34.411217  128.903980  102.086914  ...
# 100005-query -74.897130 -208.928700 -32.214005  115.582855   61.603172  ...
# 100007-query -92.343550 -530.124700  24.280703  124.623260  119.622160  ...
# 100010-query -82.446480 -530.124700  54.023262  118.234550  181.625780  ...
# 100013-query -69.850624 -759.626040  31.846502  120.052260  121.982080  ...
#
#                       62         63         64          65        66  \
# Id
# 100004-query -123.770250  45.635944 -134.25893   13.735359  70.61763
# 100005-query  -64.934890  37.824436 -153.04173 -131.257920  68.26281
# 100007-query -121.699980  49.379295 -211.29207   37.299725  68.56667
# 100010-query  -61.568954  35.105920 -134.64563   -7.372177  69.39937
# 100013-query  -60.315765  45.007620 -147.07414   34.577280  65.68382
#
#                       67         68          69          70          71
# Id
# 100004-query   15.332115  154.56812  101.700640 -1171.89230 -125.307890
# 100005-query   56.239280  120.64690   76.342550 -1156.99290  -72.146390
# 100007-query   21.038134   37.36427  116.667170 -1129.24290  -87.194520
# 100010-query   16.125835  202.46930  120.868460  -195.12244 -121.981840
# 100013-query  251.287280   96.05116  110.661316  -560.48190  -13.711834
#
# [5 rows x 72 columns]
# <class 'pandas.core.frame.DataFrame'>
# Index: 20000 entries, 100004-query to 199997-query
# Data columns (total 72 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       20000 non-null  float64
#  1   1       20000 non-null  float64
#  2   2       20000 non-null  float64
#  3   3       20000 non-null  float64
#  4   4       20000 non-null  float64
#  5   5       20000 non-null  float64
#  6   6       20000 non-null  float64
#  7   7       20000 non-null  float64
#  8   8       20000 non-null  float64
#  9   9       20000 non-null  float64
#  10  10      20000 non-null  float64
#  11  11      20000 non-null  float64
#  12  12      20000 non-null  float64
# 100010-query  -82.446480 -530.124700  54.023262  118.234550  181.625780  ...
# 100013-query  -69.850624 -759.626040  31.846502  120.052260  121.982080  ...
# ...                  ...         ...        ...         ...         ...  ...
# 199985-query  -47.269127 -530.124700 -69.155650  127.315640  112.201080  ...
# 199986-query -107.004950 -262.447080 -79.050070  124.050520  153.747590  ...
# 199990-query -112.755660 -452.162570   4.730866  124.163994   82.169110  ...
# 199994-query  -32.786840 -759.626040 -16.677721  119.300580  234.239720  ...
# 199997-query  -63.278100 -109.805060  16.277431  128.150040  168.835420  ...
#
#                       62         63          64          65         66  \
# Id
# 100004-query -123.770250  45.635944 -134.258930   13.735359  70.617630
# 100005-query  -64.934890  37.824436 -153.041730 -131.257920  68.262810
# 100007-query -121.699980  49.379295 -211.292070   37.299725  68.566670
# 100010-query  -61.568954  35.105920 -134.645630   -7.372177  69.399370
# 100013-query  -60.315765  45.007620 -147.074140   34.577280  65.683820
# ...                  ...        ...         ...         ...        ...
# 199985-query -134.048000  38.803470 -116.340195   64.255180  64.844820
# 199986-query  -83.439800   4.323893 -149.993960  102.223570  65.324875
# 199990-query  -84.164604  55.030460 -212.715420  158.224700  67.100230
# 199994-query -130.404600  32.295530 -128.106570  -86.121800  68.416960
# 199997-query  -48.826626  39.679783 -149.336460  160.609920  71.559220
#
#                       67         68          69           70          71
# Id
# 100004-query   15.332115  154.56812  101.700640 -1171.892300 -125.307890
# 100005-query   56.239280  120.64690   76.342550 -1156.992900  -72.146390
# 100007-query   21.038134   37.36427  116.667170 -1129.242900  -87.194520
# 100010-query   16.125835  202.46930  120.868460  -195.122440 -121.981840
# 100013-query  251.287280   96.05116  110.661316  -560.481900  -13.711834
# ...                  ...        ...         ...          ...         ...
# 199985-query   29.071762   57.99832  112.556820  -507.231870  -29.546663
# 199986-query  120.794280   78.84816  165.904390 -1074.464800  -42.413544
# 199990-query   33.019867   78.67172  118.599700 -1074.464800  -73.706180
# 199994-query   49.543694  167.95978  137.513920   -91.521515  -52.377990
# 199997-query   25.237282  -35.98545   97.924790    73.080770  -28.081186
#
# [20000 rows x 72 columns]>

# %%
describe_data(validation_answer)
# Out:
#                   Expected
# Id
# 100004-query    75484-base
# 100005-query  1905037-base
# 100007-query  1533713-base
# 100010-query   641788-base
# 100013-query    11032-base
# <class 'pandas.core.frame.DataFrame'>
# Index: 20000 entries, 100004-query to 199997-query
# Data columns (total 1 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Expected  20000 non-null  object
# dtypes: object(1)
# memory usage: 312.5+ KB
# None
# Описание
# <bound method NDFrame.describe of                   Expected
# Id
# 100004-query    75484-base
# 100005-query  1905037-base
# 100007-query  1533713-base
# 100010-query   641788-base
# 100013-query    11032-base
# ...                    ...
# 199985-query   252939-base
# 199986-query   112084-base
# 199990-query   364908-base
# 199994-query   148812-base
# 199997-query  1690782-base
#
# [20000 rows x 1 columns]>

# %% [markdown]
# Подготовим данные для обучения модели

# %%
targets = train["Target"]

# %%
train.drop("Target", axis=1, inplace=True)

# %% [markdown]
# Посмотрим есть ли корреляции между признаками.

# %%
corr = base.corr()
corr.style.background_gradient(cmap='RdYlGn')
#T_32f8b_row41_col55, #T_32f8b_row41_col71, #T_32f8b_row42_col0, #T_32f8b_row42_col3, #T_32f8b_row43_col50, #T_32f8b_row43_col70, #T_32f8b_row44_col2, #T_32f8b_row44_col31, #T_32f8b_row44_col50, #T_32f8b_row44_col52, #T_32f8b_row44_col56, #T_32f8b_row44_col67, #T_32f8b_row45_col17, #T_32f8b_row45_col67, #T_32f8b_row45_col70, #T_32f8b_row46_col6, #T_32f8b_row46_col13, #T_32f8b_row46_col21, #T_32f8b_row46_col28, #T_32f8b_row46_col66, #T_32f8b_row47_col20, #T_32f8b_row47_col31, #T_32f8b_row48_col12, #T_32f8b_row48_col24, #T_32f8b_row48_col56, #T_32f8b_row48_col64, #T_32f8b_row49_ ...

# %%
# %%time
for i in base.columns:
    plt.figure(figsize=(15,5), dpi= 80)
    base[i].plot(kind='hist', grid=True, bins = 50)
    plt.xlabel(f'Признаки, {i}')
    plt.ylabel('Плотность признака');
# Out:
# <timed exec>:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
# CPU times: total: 6.98 s
# Wall time: 6.98 s

# %%
base.hist(figsize=[25,20], bins=50);

# %% [markdown]
# **Вывод:**
#
# Также как и в основных данных, в мини датасетах пропусков нет.  Существенной корреляции между признаками не обнаружено.
#
# На графиках распределения признаков видно, что некоторые признаки распределены не нормально, а равномерно. Обычно модели матчинга плохо работают с равномерным распределеним. Проверим эти признаки и удалим лишние для лучшей работы модели.
#
# Поскольку модели будут делать выводы о близости объектов на основании расчёта растояний до них, необходимо промасштабировать данные, чтобы признаки, значения которых в миллион раз более высокие чем у других, не вопринимвлись моделью как более значимые.

# %% [markdown]
# **Вывод:**
#
# Пропусков в данных нет. Разброс данных довольно большой. Это значит, что для корректной работы модели обязательно понадобится масштабирование признаков. Существенной корреляции между признаками не обнаружено.
#
# В base почти 3 миллиона объектов. Необходимо будет обратить внимание на время работы модели при её выборе.

# %% [markdown]
# ## Подготовка данных

# %% [markdown]
# ### Масштабирование данных

# %%
# %%time
scaler = StandardScaler()
scaler.fit(base[base.columns])
base[base.columns] = scaler.transform(base[base.columns])
train[base.columns] = scaler.transform(train[base.columns])
validation[base.columns] = scaler.transform(validation[base.columns])
# Out:
# CPU times: total: 672 ms
# Wall time: 661 ms

# %%
validation
# Out:
#                        0          1           2          3           4  \
# Id
# 100004-query  -79.532920  -0.364173  -16.027431 -170.88495  165.453920
# 100005-query  -89.745360   6.317698  -80.744650 -114.53197  153.960340
# 100007-query -119.026850   7.536469  -62.973827 -142.94609  150.376110
# 100010-query  -57.710420   5.344710  -36.634872 -151.92635  123.258860
# 100013-query -113.839820   5.682194   -7.384804 -142.80922   63.082832
# ...                  ...        ...         ...        ...         ...
# 199985-query -129.697630   5.962259 -100.910480 -156.47946  178.207900
# 199986-query  -52.005882   2.728153  -15.433735 -153.53885  116.619530
# 199990-query  -64.395600   7.386747  -42.248030 -138.83315  107.673060
# 199994-query  -73.456550  10.805204  -28.588137 -163.68158   71.399506
# 199997-query  -59.224453  13.585838   22.655106 -134.92603  145.205690
#
#                        5           6          7           8           9  ...  \
# Id                                                                       ...
# 100004-query  -28.291668   33.931934  34.411217  128.903980  102.086914  ...
# 100005-query  -74.897130 -208.928700 -32.214005  115.582855   61.603172  ...
# 100007-query  -92.343550 -530.124700  24.280703  124.623260  119.622160  ...
# 100010-query  -82.446480 -530.124700  54.023262  118.234550  181.625780  ...
# 100013-query  -69.850624 -759.626040  31.846502  120.052260  121.982080  ...
# ...                  ...         ...        ...         ...         ...  ...
# 199985-query  -47.269127 -530.124700 -69.155650  127.315640  112.201080  ...
# 199986-query -107.004950 -262.447080 -79.050070  124.050520  153.747590  ...
# 199990-query -112.755660 -452.162570   4.730866  124.163994   82.169110  ...
# 199994-query  -32.786840 -759.626040 -16.677721  119.300580  234.239720  ...
# 199997-query  -63.278100 -109.805060  16.277431  128.150040  168.835420  ...
#
#                       62         63          64          65         66  \
# Id
# 100004-query -123.770250  45.635944 -134.258930   13.735359  70.617630
# 100005-query  -64.934890  37.824436 -153.041730 -131.257920  68.262810
# 100007-query -121.699980  49.379295 -211.292070   37.299725  68.566670
# 100010-query  -61.568954  35.105920 -134.645630   -7.372177  69.399370
# 100013-query  -60.315765  45.007620 -147.074140   34.577280  65.683820
# ...                  ...        ...         ...         ...        ...
# 199985-query -134.048000  38.803470 -116.340195   64.255180  64.844820
# 199986-query  -83.439800   4.323893 -149.993960  102.223570  65.324875
# 199990-query  -84.164604  55.030460 -212.715420  158.224700  67.100230
# 199994-query -130.404600  32.295530 -128.106570  -86.121800  68.416960
# 199997-query  -48.826626  39.679783 -149.336460  160.609920  71.559220
#
#                       67         68          69           70          71
# Id
# 100004-query   15.332115  154.56812  101.700640 -1171.892300 -125.307890
# 100005-query   56.239280  120.64690   76.342550 -1156.992900  -72.146390
# 100007-query   21.038134   37.36427  116.667170 -1129.242900  -87.194520
# 100010-query   16.125835  202.46930  120.868460  -195.122440 -121.981840
# 100013-query  251.287280   96.05116  110.661316  -560.481900  -13.711834
# ...                  ...        ...         ...          ...         ...
# 199985-query   29.071762   57.99832  112.556820  -507.231870  -29.546663
# 199986-query  120.794280   78.84816  165.904390 -1074.464800  -42.413544
# 199990-query   33.019867   78.67172  118.599700 -1074.464800  -73.706180
# 199994-query   49.543694  167.95978  137.513920   -91.521515  -52.377990
# 199997-query   25.237282  -35.98545   97.924790    73.080770  -28.081186
#
# [20000 rows x 72 columns]

# %% [markdown]
# ### Удаление лишних признаков

# %% [markdown]
# Напишем цикл, который проверяет отрицательно или положительно влияет каждый признак на метрику модели. В качестве модели выбирем NearestNeighbors. На небольшом наборе данных она работает достаточно быстро.

# %%
neigh = NearestNeighbors(n_neighbors=5, algorithm = 'auto', n_jobs = -1)

# %%
# %%time
# Определим метрику модели, которая работает со всеми признаками
neigh.fit(base)
distances, indices = neigh.kneighbors(train)

base_index = {k: v for k, v in enumerate(base.index.to_list())}

acc = 0
for target, el in zip(targets.values.tolist(), indices.tolist()):
    acc += int(target in [base_index[r] for r in el])
acc_base = 100 * acc / len(indices)
print(acc_base, "%")
# Out:
# 72.44 %
# CPU times: total: 1min 43s
# Wall time: 14.4 s

# %%
# %%time

col_to_drop = []

for col in base.columns:
    base_sample = base.drop(columns = col, axis = 1)
    train_sample = train.drop(columns = col, axis = 1)
    base_index = {k: v for k, v in enumerate(base_sample.index.to_list())}
    
    neigh.fit(base_sample)
    distances, indices = neigh.kneighbors(train_sample)
    
    acc = 0
    for target, el in zip(targets.values.tolist(), indices.tolist()):
        acc += int(target in [base_index[r] for r in el])
        acc_new = 100 * acc / len(indices)

    if acc_new > acc_base:
        col_to_drop.append(col)
        print(col, acc_new, "%")
# Out:
# 8 72.445 %
# 21 73.085 %
# 25 73.05 %
# 33 74.1 %
# 44 72.505 %
# 59 72.845 %
# 65 72.875 %
# CPU times: total: 2h 24min
# Wall time: 19min 23s

# %%
col_to_drop
# Out:
# ['8', '21', '25', '33', '44', '59', '65']

# %%
def drop_features_list(df_list, col_list):
    for data in df_list:
        print("Количество признаков в", data, "до", globals()[data].shape[1])
        globals()[data] = globals()[data].drop(columns = col_list, axis = 1)
        print("Количество признаков в", data, "после", globals()[data].shape[1], '\n')

# %%
df_list = ['base', 'train', 'validation']
drop_features_list(df_list, col_to_drop)
# Out:
# Количество признаков в base до 72
# Количество признаков в base после 65
#
# Количество признаков в train до 72
# Количество признаков в train после 65
#
# Количество признаков в validation до 72
# Количество признаков в validation после 65

# %% [markdown]
# **Вывод**
#
# Мы удалили признаки, которые отрицательно влияют на метрику aacuracy модели. Заметим, что 6 из 7 таких признаков распределены равномерно.
#
# Проверим улучшилась ли метрика.

# %% [markdown]
# ## NearestNeighbors

# %% [markdown]
# Для начала, попробуем решить задачу матчинга с помощью NearestNeighbors. Запомним метрику, а также время работы модели для последующего сравнения.

# %%
# %%time
start_time = time.time()

neigh = NearestNeighbors(n_neighbors=5, algorithm = 'auto', n_jobs = -1)
neigh.fit(base)

end_time = time.time()  # время окончания выполнения
learn_time_neigh = end_time - start_time  # вычисляем время выполнения

print(f"Время выполнения программы: {learn_time_neigh} секунд")
# Out:
# Время выполнения программы: 0.1810314655303955 секунд
# CPU times: total: 172 ms
# Wall time: 181 ms

# %%
start_time = time.time()  # время начала выполнения

distances, indices = neigh.kneighbors(train)


end_time = time.time()  # время окончания выполнения
ex_time_neigh = end_time - start_time  # вычисляем время выполнения

print(f"Время выполнения программы: {ex_time_neigh} секунд")
# Out:
# Время выполнения программы: 13.104973793029785 секунд

# %%
base_index = {k: v for k, v in enumerate(base.index.to_list())}

# %%
acc = 0
for target, el in zip(targets.values.tolist(), indices.tolist()):
    acc += int(target in [base_index[r] for r in el])

acc_neigh = 100 * acc / len(indices)
print(acc_neigh, "%")
# Out:
# 76.525 %

# %% [markdown]
# **Вывод**
#
# На тестовом наборе данных модель показала достатчно высокую метрику и неплохое время.

# %% [markdown]
# <div class="alert alert-info">
# <img src="http://s3.amazonaws.com/pix.iemoji.com/images/emoji/apple/ios-12/256/waving-hand.png" align=left width=30, heigth=30>
# </div>
# <b> Комментарий ревьюера</b>
#
# 1. ✅ Хорошо, что ты испольовала нестандартный подход, без FAISS.
# 2. ⚠️ Не очень хорошо, что нет данных. Все таки мы ближе к точным наукам, какая метрика у тебя получилась, в цифрах?

# %% [markdown]
# ## Faiss

# %% [markdown]
# Попробуем решить задачу при помощи библиотеки Faiss.
#
# Подготовим векторы признаков для работы с ней.

# %%
vectors = np.ascontiguousarray(base.values).astype('float32')
vectors
# Out:
# array([[-1.8443022 ,  0.93893456, -0.935685  , ...,  1.0972053 ,
#         -0.74412334,  1.1043065 ],
#        [-0.51272416, -0.4724193 , -1.1424218 , ...,  0.07225417,
#         -0.9527734 , -0.6042021 ],
#        [ 0.68306684, -1.7964917 , -0.08898446, ...,  0.24632435,
#         -0.8001696 , -0.4060992 ],
#        ...,
#        [-0.89883244, -0.5086265 ,  0.5724815 , ..., -1.0343795 ,
#         -0.7541969 , -1.0281959 ],
#        [-0.43820024, -2.0391517 , -0.69410026, ...,  0.65902364,
#         -0.7541969 ,  1.266724  ],
#        [-0.03263538,  0.18789445,  0.246153  , ...,  0.43827665,
#         -0.7541969 , -0.18702407]], dtype=float32)

# %%
query = np.ascontiguousarray(train.values).astype('float32')
query
# Out:
# array([[-0.06997188, -0.23626551,  0.31797427, ...,  0.70854634,
#         -0.65375054, -0.0786078 ],
#        [-0.8648819 ,  0.0570279 ,  1.178796  , ..., -1.3781694 ,
#         -0.44171497, -1.7140754 ],
#        [ 0.8549507 , -0.32229775,  1.7342216 , ...,  0.47491172,
#         -1.0227495 , -0.01834789],
#        ...,
#        [ 1.9101757 ,  0.7081306 ,  0.6515225 , ..., -1.0136383 ,
#          1.9845161 , -0.6216205 ],
#        [ 0.9519045 ,  0.21919523,  0.16883157, ..., -0.260151  ,
#         -1.1758906 , -0.2547296 ],
#        [ 0.7100782 ,  0.740952  , -0.4852221 , ..., -0.39911252,
#         -0.7541969 ,  0.30937594]], dtype=float32)

# %% [markdown]
# ### IndexFlatL2

# %% [markdown]
# Начнём с 'flat' индексов, которые не модифицируют вектора.

# %%
dim = base.shape[1]
index = faiss.IndexFlatL2(dim)

# %%
# %%time
start_time = time.time()

print(index.is_trained)
index.add(vectors)
print(index.ntotal)

end_time = time.time()  # время окончания выполнения
learn_time_IndexFlatL2 = end_time - start_time  # вычисляем время выполнения

print(f"Время выполнения программы: {learn_time_IndexFlatL2} секунд")
# Out:
# True
# 583600
# Время выполнения программы: 0.024005889892578125 секунд
# CPU times: total: 31.2 ms
# Wall time: 24 ms

# %%
# %%time
start_time = time.time()  # время начала выполнения

k = 5
D, I = index.search(query, k)

end_time = time.time()  # время окончания выполнения
ex_time_IndexFlatL2 = end_time - start_time  # вычисляем время выполнения

print(f"Время выполнения программы: {ex_time_IndexFlatL2} секунд")
# Out:
# Время выполнения программы: 630.802971124649 секунд
# CPU times: total: 1h 29min 14s
# Wall time: 10min 30s

# %%
base_index = {k: v for k, v in enumerate(base.index.to_list())}

# %%
acc = 0
for target, el in zip(targets_mini.values.tolist(), I.tolist()):
    acc += int(target in [base_index[i] for i in el])

acc_IndexFlatL2 = 100 * acc / len(I)
print(acc_IndexFlatL2, "%")
# Out:
# 76.525 %

# %% [markdown]
# **Вывод**
#
# Поскольку данные типы индексов не используют кластеризацию, они выдают довольно высокое качество матчинга, ондако при большом объёме данные работают очень медленно.

# %% [markdown]
# **Вывод**
#
# IndexFlatIP показал худшие результаты и по точности, и по времени.

# %% [markdown]
# <div class="alert alert-info">
# <img src="http://s3.amazonaws.com/pix.iemoji.com/images/emoji/apple/ios-12/256/waving-hand.png" align=left width=30, heigth=30>
# </div>
# <b> Комментарий ревьюера</b>
#
# 1. Хорошо. Второй подход есть.
# 2. Но если ты почитаешь документацию, то там и не рекомендуется плоский вектор.

# %% [markdown]
# ### HNSW index

# %%
start_time = time.time()
# set HNSW index parameters
M = 64 #64  # number of connections each vertex will have
ef_search = 96  # depth of layers explored during search
ef_construction = 64  # depth of layers explored during index construction
dim = base.shape[1]
# initialize index
index = faiss.IndexHNSWFlat(dim, M)
# set efConstruction and efSearch parameters
index.hnsw.efConstruction = ef_construction
index.hnsw.efSearch = ef_search
# add data to index
index.add(vectors)

end_time = time.time()  # время окончания выполнения
learn_time_HNSW = end_time - start_time  # вычисляем время выполнения

print(f"Время выполнения программы: {learn_time_HNSW} секунд")
# Out:
# Время выполнения программы: 53.27930474281311 секунд

# %%
start_time = time.time()  # время начала выполнения

index.nprobe = 40  # Проходим по топ-16 центроид для поиска top-n ближайших соседей

D, I = index.search(query, 5)

end_time = time.time()  # время окончания выполнения
ex_time_HNSW = end_time - start_time  # вычисляем время выполнения

print(f"Время выполнения программы: {ex_time_HNSW} секунд")
# Out:
# Время выполнения программы: 1.2037756443023682 секунд

# %%
base_index = {k: v for k, v in enumerate(base.index.to_list())}

# %%
acc = 0
for target, el in zip(targets.values.tolist(), I.tolist()):
    acc += int(target in [base_index[B] for B in el])

acc_HNSW = 100 * acc / len(I)
print(acc_HNSW, "%")
# Out:
# 75.9 %

# %% [markdown]
# **Вывод**
#
# HNSW index показывает хорошую метрику и очень короткое время. Однако при обработке большого датасета потребует больших затрат памяти.

# %% [markdown]
# ### IndexIVFFlat

# %% [markdown]
# Перейдём к IndexIVFFlat.
#
# Попробуем подобрать лучшие параметры для разделения на кластеры nlist и количества кластеров, в которых будет производится поиск nprobe.

# %%
dim = base.shape[1]
quantizer = faiss.IndexFlatL2(dim) 
#quantiser = faiss.IndexFlatIP(dim)

base_index = {k: v for k, v in enumerate(base.index.to_list())}

# %%
# %%time

nlist_list = []
nprobe_list = []
acc_list = []
time_list = []

for nlist_s in [100, 500, 1000]:
    nlist = nlist_s
    index = faiss.IndexIVFFlat(quantizer, dim, nlist, faiss.METRIC_L2) #METRIC_INNER_PRODUCT
    index.train(vectors)
    index.add(vectors)
    

    for nprobe_s in [5, 10, 40]:
        index.nprobe = nprobe_s       
        start_time = time.time()
        D, I = index.search(query, 5) 
        end_time = time.time()  # время окончания выполнения
        ex_time = round(end_time - start_time, 3) # вычисляем время выполнения
        
        acc = 0
        for target, el in zip(targets.values.tolist(), I.tolist()):
            acc += int(target in [base_index[B] for B in el])
        
        nlist_list.append(nlist_s)
        nprobe_list.append(nprobe_s)
        acc_list.append(100 * acc / len(I))
        time_list.append(ex_time)
    
        
        
        print(nlist_s, nprobe_s, 100 * acc / len(I), ex_time)
        
        #print(f"Время выполнения программы: {ex_time_IndexIVFFlat} секунд")
# Out:
# 100 5 74.685 4.788
# 100 10 75.54 9.275
# 100 40 76.29 39.329
# 500 5 73.515 1.028
# 500 10 74.705 1.833
# 500 40 75.71 5.735
# 1000 5 72.935 0.637
# 1000 10 74.43 1.043
# 1000 40 75.51 3.047
# CPU times: total: 56min 30s
# Wall time: 5min 20s

# %%
#convert lists into a single list
data = []
data.append(nlist_list)
data.append(nprobe_list)
data.append(acc_list)
data.append(time_list)


#convert list into DataFrame
df = pd.DataFrame(data).transpose()
df.columns =['nlist', 'nprobe', 'acc', 'time']

#view resulting DataFrame
df
# Out:
#     nlist  nprobe     acc    time
# 0   100.0     5.0  74.685   4.788
# 1   100.0    10.0  75.540   9.275
# 2   100.0    40.0  76.290  39.329
# 3   500.0     5.0  73.515   1.028
# 4   500.0    10.0  74.705   1.833
# 5   500.0    40.0  75.710   5.735
# 6  1000.0     5.0  72.935   0.637
# 7  1000.0    10.0  74.430   1.043
# 8  1000.0    40.0  75.510   3.047

# %%
dim = base.shape[1] #how many partitions we’d like our index to have
nlist = 500 # количество кластеров 141
quantizer = faiss.IndexFlatL2(dim) 
#quantiser = faiss.IndexFlatIP(dim)
index = faiss.IndexIVFFlat(quantizer, dim, nlist, faiss.METRIC_L2) #METRIC_INNER_PRODUCT

# %%
# %%time

start_time = time.time()

#Запускаем обучение:
print(index.is_trained)   # False.
index.train(vectors)  # Train на нашем наборе векторов
 
# Обучение завершено, но векторов в индексе пока нет, так что добавляем их в индекс:
print(index.is_trained)  # True
print(index.ntotal)   # 0
index.add(vectors)
print(index.ntotal)   # 1000000

end_time = time.time()  # время окончания выполнения
learn_time_IndexIVFFlat = end_time - start_time  # вычисляем время выполнения

print(f"Время выполнения программы: {learn_time_IndexIVFFlat} секунд")
# Out:
# False
# True
# 0
# 583600
# Время выполнения программы: 65.56884837150574 секунд
# CPU times: total: 13min 29s
# Wall time: 1min 5s

# %%
start_time = time.time()  # время начала выполнения

index.nprobe = 40 #int(math.sqrt(base_mini.shape[0]))  # Проходим по топ-16 центроид для поиска top-n ближайших соседей
D, I = index.search(query, 5) 

end_time = time.time()  # время окончания выполнения
ex_time_IndexIVFFlat = end_time - start_time  # вычисляем время выполнения

print(f"Время выполнения программы: {ex_time_IndexIVFFlat} секунд")
# Out:
# Время выполнения программы: 5.657338380813599 секунд

# %%
base_index = {k: v for k, v in enumerate(base.index.to_list())}

# %%
acc = 0
for target, el in zip(targets.values.tolist(), I.tolist()):
    acc += int(target in [base_index[B] for B in el])

acc_IndexIVFFlat_L2 = 100 * acc / len(I)
print(acc_IndexIVFFlat_L2, "%")
# Out:
# 75.71 %

# %% [markdown]
# **Вывод**
#
# Лучший результат показала модель с наименьших количеством кластеров - 100, и наибольшим количеством nprobe - 40. Однако она же наиболее затратна по времени. Стоит выбрать модель с количеством кластеров - 500, и количеством nprobe - 40, так как её метрика очень близка к лучшей, а времени она затричивает гораздо меньше.

# %% [markdown]
# <div class="alert alert-info">
# <img src="http://s3.amazonaws.com/pix.iemoji.com/images/emoji/apple/ios-12/256/waving-hand.png" align=left width=30, heigth=30>
# </div>
# <b> Комментарий ревьюера</b>
#
# 1. Появились какие-то цифры, уже лучше.
# 2. Но по прежнему, их мало.

# %% [markdown]
# ## Итог

# %%
# final_data = pd.DataFrame({'Модель' : ['NearestNeighbors', 'IndexFlatL2', 'IndexFlatIP', 'IndexIVFFlat_METRIC_L2', 'METRIC_INNER_PRODUCT', 'HNSW',],
#                           'Accuracy_5' : [acc_neigh, acc_IndexFlatL2, acc_IndexFlatIP, acc_IndexIVFFlat_L2, acc_MIP, acc_HNSW],
#                           'Время_обучения' : [learn_time_neigh, learn_time_IndexFlatL2, learn_time_IndexFlatIP, learn_time_IndexIVFFlat, learn_time_MIP, learn_time_HNSW],
#                           'Время_выполнения' : [ex_time_neigh, ex_time_IndexFlatL2, ex_time_IndexFlatIP, ex_time_IndexIVFFlat, ex_time_MIP, ex_time_HNSW]})

# final_data['Общее_время'] = final_data['Время_обучения'] + final_data['Время_выполнения']
# final_data

# %%
final_data = pd.DataFrame({'Модель' : ['NearestNeighbors', 'IndexFlatL2', 'IndexIVFFlat_METRIC_L2', 'HNSW',],
                          'Accuracy_5' : [acc_neigh, acc_IndexFlatL2, acc_IndexIVFFlat_L2, acc_HNSW],
                          'Время_обучения' : [learn_time_neigh, learn_time_IndexFlatL2, learn_time_IndexIVFFlat, learn_time_HNSW],
                          'Время_выполнения' : [ex_time_neigh, ex_time_IndexFlatL2, ex_time_IndexIVFFlat, ex_time_HNSW]})

final_data['Общее_время'] = final_data['Время_обучения'] + final_data['Время_выполнения']
final_data
# Out:
#                    Модель  Accuracy_5  Время_обучения  Время_выполнения  \
# 0        NearestNeighbors      76.525        0.181031         13.104974
# 1             IndexFlatL2      76.525        0.024006        630.802971
# 2  IndexIVFFlat_METRIC_L2      75.710       65.568848          5.657338
# 3                    HNSW      75.900       53.279305          1.203776
#
#    Общее_время
# 0    13.286005
# 1   630.826977
# 2    71.226187
# 3    54.483080

# %% [markdown]
# **Вывод**
#
# По итогам тестирования лучшие результаты точности показали модели NearestNeighbors и faiss с индексом IndexFlatL2. Однако NearestNeighbors существенно выигрывает по времени.

# %% [markdown]
# <div class="alert alert-info">
# <img src="http://s3.amazonaws.com/pix.iemoji.com/images/emoji/apple/ios-12/256/waving-hand.png" align=left width=30, heigth=30>
# </div>
# <b> Комментарий ревьюера</b>
#
# 1. Интрига сохраняется, что лучше, почему лучше?
# 2. Представь, у твоего работадателя набора нет, и он тебя проверяет. Одни загадки.

# %% [markdown]
# ## Full dataset

# %% [markdown]
# Перейдём к работе на всём датасете.

# %%
base, train, validation, validation_answer = load_data(path, 'full')

# %%
describe_data(base)
# Out:
#                  0          1          2          3           4           5  \
# Id
# 0-base -115.083890  11.152912 -64.426760 -118.88089  216.482440 -104.698060
# 1-base  -34.562202  13.332763 -69.787610 -166.53348   57.680607  -86.098370
# 2-base  -54.233746   6.379371 -29.210136 -133.41383  150.895830  -99.435326
# 3-base  -87.520130   4.037884 -87.803030 -185.06763   76.369540  -58.985165
# 4-base  -72.743850   6.522049  43.671265 -140.60803    5.820023 -112.074080
#
#                  6          7           8           9  ...          62  \
# Id                                                     ...
# 0-base -469.070588  44.348083  120.915344  181.449700  ...  -42.808693
# 1-base  -85.076666 -35.637436  119.718636  195.234190  ... -117.767525
# 2-base   52.554795  62.381706  128.951450  164.381470  ...  -76.397800
# 3-base -383.182845 -33.611237  122.031910  136.233580  ...  -70.647940
# 4-base -397.711282  45.182500  122.167180  112.119064  ...  -57.199104
#
#                63         64          65        66         67          68  \
# Id
# 0-base  38.800827 -151.76218  -74.389090  63.66634  -4.703861   92.933610
# 1-base  41.100000 -157.82940  -94.446806  68.20211  24.346846  179.937930
# 2-base  46.011803 -207.14442  127.325570  65.56618  66.325680   81.073490
# 3-base  -6.358921 -147.20105  -37.692750  66.20289 -20.566910  137.206940
# 4-base  56.642403 -159.35184   85.944724  66.76632  -2.505783   65.315285
#
#                 69           70         71
# Id
# 0-base  115.269190  -112.756640 -60.830353
# 1-base  116.834000   -84.888941 -59.524610
# 2-base  116.594154 -1074.464888 -32.527206
# 3-base  117.474100 -1074.464888 -72.915490
# 4-base  135.051590 -1074.464888   0.319401
#
# [5 rows x 72 columns]
# <class 'pandas.core.frame.DataFrame'>
# Index: 2918139 entries, 0-base to 4744766-base
# Data columns (total 72 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   0       float64
#  1   1       float64
#  2   2       float64
#  3   3       float64
#  4   4       float64
#  5   5       float64
#  6   6       float64
#  7   7       float64
#  8   8       float64
#  9   9       float64
#  10  10      float64
#  11  11      float64
#  12  12      float64
#  13  13      float64
#  14  14      float64
#  15  15      float64
#  16  16      float64
#  17  17      float64
#  18  18      float64
#  19  19      float64
#  20  20      float64
#  21  21      float64
#  22  22      float64
#  23  23      float64
#  24  24      float64
#  25  25      float64
#  26  26      float64
#  27  27      float64
#  28  28      float64
#  29  29      float64
#  30  30      float64
#  31  31      float64
#  32  32      float64
#  33  33      float64
#  34  34      float64
#  35  35      float64
#  36  36      float64
#  37  37      float64
#  38  38      float64
#  39  39      float64
#  40  40      float64
#  41  41      float64
#  42  42      float64
#  43  43      float64
#  44  44      float64
#  45  45      float64
#  46  46      float64
#  47  47      float64
#  48  48      float64
#  49  49      float64
#  50  50      float64
#  51  51      float64
#  52  52      float64
#  53  53      float64
#  54  54      float64
#  55  55      float64
#  56  56      float64
#  57  57      float64
#  58  58      float64
#  59  59      float64
#  60  60      float64
#  61  61      float64
#  62  62      float64
#  63  63      float64
#  64  64      float64
#  65  65      float64
#  66  66      float64
#  67  67      float64
#  68  68      float64
#  69  69      float64
#  70  70      float64
#  71  71      float64
# dtypes: float64(72)
# memory usage: 1.6+ GB
# None
# Описание
# <bound method NDFrame.describe of                        0          1          2          3           4  \
# Id
# 0-base       -115.083890  11.152912 -64.426760 -118.88089  216.482440
# 1-base        -34.562202  13.332763 -69.787610 -166.53348   57.680607
# 2-base        -54.233746   6.379371 -29.210136 -133.41383  150.895830
# 99998-query  57.748695 -186.625340  -93.810520  66.186200  -39.842730
# 99999-query   5.184549 -134.788450  -78.863722  66.884630   45.619125
#
#                      68          69           70          71        Target
# Id
# 0-query       62.642094  134.763600  -415.750254  -25.958572   675816-base
# 1-query       89.974976  130.589630 -1035.092211  -51.276833   366656-base
# 2-query      212.409730  121.931470 -1074.464888  -22.547178  1447819-base
# 3-query       83.178760  118.277725 -1074.464888  -19.902788  1472602-base
# 4-query       77.621765   92.479930 -1074.464888  -21.149351   717819-base
# ...                 ...         ...          ...         ...           ...
# 99995-query   61.689774  107.037950 -1074.464888  -35.128250   811868-base
# 99996-query  133.784000  154.495860 -1144.590904 -108.663510  1460772-base
# 99997-query   35.785603  111.616710  -714.897734   -4.270569  2366140-base
# 99998-query   56.899708  110.702940 -1074.464888  -79.494965     9252-base
# 99999-query  129.991240  100.656710   -43.558286  -80.152910  2769109-base
#
# [100000 rows x 73 columns]>

# %%
describe_data(validation)
# Out:
#                       0          1          2          3          4  \
# Id
# 100000-query -57.372734   3.597752 -13.213642 -125.92679  110.74594
# 100001-query -53.758705  12.790300 -43.268543 -134.41762  114.44991
# 100002-query -64.175095  -3.980927  -7.679249 -170.16093   96.44616
# 100003-query -99.286860  16.123936   9.837166 -148.06044   83.69708
# 100004-query -79.532920  -0.364173 -16.027431 -170.88495  165.45392
#
#                        5           6           7           8           9  ...  \
# Id                                                                        ...
# 100000-query  -81.279594 -461.003172  139.815720  112.880980   75.215750  ...
# 100001-query  -90.520130 -759.626065   63.995087  127.117905   53.128998  ...
# 100002-query  -62.377740 -759.626065   87.477554  131.270110  168.920320  ...
# 100003-query -133.729720   58.576403  -19.046660  115.042404   75.206730  ...
# 100004-query  -28.291668   33.931936   34.411217  128.903980  102.086914  ...
#
#                      62         63         64          65        66  \
# Id
# 100000-query  -75.51302  52.830902 -143.43945   59.051935  69.28224
# 100001-query  -79.44183  29.185436 -168.60590  -82.872443  70.76560
# 100002-query -134.79541  37.368730 -159.66231 -119.232725  67.71044
# 100003-query  -77.23611  44.100494 -132.53012 -106.318982  70.88396
# 100004-query -123.77025  45.635944 -134.25893   13.735359  70.61763
#
#                      67         68          69           70          71
# Id
# 100000-query  61.927513  111.59253  115.140656 -1099.130485 -117.079360
# 100001-query -65.975950   97.07716  123.391640  -744.442332  -25.009320
# 100002-query  86.002060  137.63641  141.081630  -294.052271  -70.969604
# 100003-query  23.577892  133.18396  143.252940  -799.363667  -89.392670
# 100004-query  15.332115  154.56812  101.700640 -1171.892332 -125.307890
#
# [5 rows x 72 columns]
# <class 'pandas.core.frame.DataFrame'>
# Index: 100000 entries, 100000-query to 199999-query
# Data columns (total 72 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   0       100000 non-null  float64
#  1   1       100000 non-null  float64
#  2   2       100000 non-null  float64
#  3   3       100000 non-null  float64
#  4   4       100000 non-null  float64
#  5   5       100000 non-null  float64
#  6   6       100000 non-null  float64
#  7   7       100000 non-null  float64
#  8   8       100000 non-null  float64
#  9   9       100000 non-null  float64
#  10  10      100000 non-null  float64
#  11  11      100000 non-null  float64
#  12  12      100000 non-null  float64
#  13  13      100000 non-null  float64
# 100004-query  -28.291668   33.931936   34.411217  128.903980  102.086914  ...
# ...                  ...         ...         ...         ...         ...  ...
# 199995-query  -48.248695  -17.696937  108.150240  122.729744  103.643906  ...
# 199996-query  -89.625534   79.880236  -46.513206  123.578730   74.033020  ...
# 199997-query  -63.278100 -109.805058   16.277431  128.150040  168.835420  ...
# 199998-query  -36.508230 -759.626065  -80.221510  123.711910   32.942696  ...
# 199999-query  -59.340584 -603.133148  -42.484253  119.490900   54.073837  ...
#
#                       62         63         64          65        66  \
# Id
# 100000-query  -75.513020  52.830902 -143.43945   59.051935  69.28224
# 100001-query  -79.441830  29.185436 -168.60590  -82.872443  70.76560
# 100002-query -134.795410  37.368730 -159.66231 -119.232725  67.71044
# 100003-query  -77.236110  44.100494 -132.53012 -106.318982  70.88396
# 100004-query -123.770250  45.635944 -134.25893   13.735359  70.61763
# ...                  ...        ...        ...         ...       ...
# 199995-query  -65.641110  62.823895 -148.86781  -66.402868  66.99333
# 199996-query  -65.032900  38.019740 -113.62750  -18.436499  64.16223
# 199997-query  -48.826626  39.679783 -149.33646  160.609919  71.55922
# 199998-query  -66.512146  15.792774 -143.07475  138.192370  68.22584
# 199999-query  -81.463290  28.412325 -171.74120   96.704654  66.79330
#
#                       67          68          69           70          71
# Id
# 100000-query   61.927513  111.592530  115.140656 -1099.130485 -117.079360
# 100001-query  -65.975950   97.077160  123.391640  -744.442332  -25.009320
# 100002-query   86.002060  137.636410  141.081630  -294.052271  -70.969604
# 100003-query   23.577892  133.183960  143.252940  -799.363667  -89.392670
# 100004-query   15.332115  154.568120  101.700640 -1171.892332 -125.307890
# ...                  ...         ...         ...          ...         ...
# 199995-query   76.524155   66.525670  112.273720  -177.375834  -82.804726
# 199996-query -117.032380   94.026490   86.279526 -1271.502930  -63.491104
# 199997-query   25.237282  -35.985450   97.924790    73.080770  -28.081186
# 199998-query  115.506546  -37.607803  149.608570  -173.070396  -60.923080
# 199999-query    0.089361  175.958590  131.007740  -618.555199  -33.217857
#
# [100000 rows x 72 columns]>

# %%
describe_data(validation_answer)
# Out:
#                   Expected
# Id
# 100000-query  2676668-base
# 100001-query    91606-base
# 100002-query   472256-base
# 100003-query  3168654-base
# 100004-query    75484-base
# <class 'pandas.core.frame.DataFrame'>
# Index: 100000 entries, 100000-query to 199999-query
# Data columns (total 1 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   Expected  100000 non-null  object
# dtypes: object(1)
# memory usage: 1.5+ MB
# None
# Описание
# <bound method NDFrame.describe of                   Expected
# Id
# 100000-query  2676668-base
# 100001-query    91606-base
# 100002-query   472256-base
# 100003-query  3168654-base
# 100004-query    75484-base
# ...                    ...
# 199995-query   967418-base
# 199996-query  1344948-base
# 199997-query  1690782-base
# 199998-query   341779-base
# 199999-query   336472-base
#
# [100000 rows x 1 columns]>

# %%
targets = train["Target"]

# %%
train.drop("Target", axis=1, inplace=True)

# %%
corr = base.corr()
corr.style.background_gradient(cmap='RdYlGn')
# Out:
# <style type="text/css">
43_col70, #T_32f8b_row44_col2, #T_32f8b_row44_col31, #T_32f8b_row44_col50, #T_32f8b_row44_col52, #T_32f8b_row44_col56, #T_32f8b_row44_col67, #T_32f8b_row45_col17, #T_32f8b_row45_col67, #T_32f8b_row45_col70, #T_32f8b_row46_col6, #T_32f8b_row46_col13, #T_32f8b_row46_col21, #T_32f8b_row46_col28, #T_32f8b_row46_col66, #T_32f8b_row47_col20, #T_32f8b_row47_col31, #T_32f8b_row48_col12, #T_32f8b_row48_col24, #T_32f8b_row48_col56, #T_32f8b_row48_col64, #T_32f8b_row49_ ...

# %%
df_list = ['base', 'train', 'validation']
drop_features_list(df_list, col_to_drop)
# Out:
# Количество признаков в base до 72
# Количество признаков в base после 65
#
# Количество признаков в train до 72
# Количество признаков в train после 65
#
# Количество признаков в validation до 72
# Количество признаков в validation после 65

# %%
# %%time
scaler = StandardScaler()
scaler.fit(base[base.columns])
base[base.columns] = scaler.transform(base[base.columns])
train[base.columns] = scaler.transform(train[base.columns])
validation[base.columns] = scaler.transform(validation[base.columns])
# Out:
# CPU times: total: 3.58 s
# Wall time: 3.59 s

# %%
# %%time
vectors = np.ascontiguousarray(base.values).astype('float32')
vectors
# Out:
# CPU times: total: 1.22 s
# Wall time: 1.22 s
# array([[-1.1592162 ,  0.6203504 , -0.51372266, ..., -0.0140507 ,
#          1.7814198 , -0.3123287 ],
#        [ 2.0757148 ,  1.0604233 , -0.652491  , ...,  0.05984761,
#          1.8537259 , -0.2810519 ],
#        [ 1.2854173 , -0.34334213,  0.39787757, ...,  0.04852086,
#         -0.7138468 ,  0.36562327],
#        ...,
#        [-0.43377605, -2.064035  , -0.6909693 , ...,  0.65973157,
#         -0.7138468 ,  1.2577736 ],
#        [-0.02446461,  0.16793925,  0.25220424, ...,  0.43807346,
#         -0.7138468 , -0.19157949],
#        [-0.6321802 ,  0.96488   , -0.17634064, ..., -1.0735649 ,
#         -0.7121896 ,  1.4986584 ]], dtype=float32)

# %%
# %%time
query = np.ascontiguousarray(train.values).astype('float32')
query
# Out:
# CPU times: total: 62.5 ms
# Wall time: 46 ms
# array([[ 1.2995186 ,  1.9968884 ,  0.06377414, ...,  0.9065748 ,
#          0.99526674,  0.5229633 ],
#        [-0.06214603, -0.25715932,  0.32424858, ...,  0.70945865,
#         -0.61168975, -0.08349097],
#        [ 1.4563276 , -0.85569566, -1.851792  , ...,  0.30057615,
#         -0.7138468 ,  0.6046772 ],
#        ...,
#        [ 1.2968874 , -0.67694914,  0.3960963 , ..., -0.18653943,
#          0.219093  ,  1.0424612 ],
#        [ 0.3578639 ,  0.41189885, -0.50254726, ..., -0.22969231,
#         -0.7138468 , -0.7594065 ],
#        [-0.11325181,  0.5770834 , -0.22327293, ..., -0.70412654,
#          1.9609631 , -0.77516645]], dtype=float32)

# %%
# %%time
query_valid = np.ascontiguousarray(validation.values).astype('float32')
# Out:
# CPU times: total: 46.9 ms
# Wall time: 54 ms

# %%
# %%time
targets_valid = validation_answer['Expected']
# Out:
# CPU times: total: 0 ns
# Wall time: 4 ms

# %% [markdown]
# ### NearestNeighbors full dataset

# %%
# %%time
from sklearn.neighbors import NearestNeighbors
neigh = NearestNeighbors(n_neighbors=5, algorithm = 'auto', n_jobs = -1)
neigh.fit(base)
# Out:
# CPU times: total: 1.14 s
# Wall time: 1.14 s
# NearestNeighbors(n_jobs=-1)

# %%
# %%time
start_time = time.time()  # время начала выполнения

distances, indices = neigh.kneighbors(train)


end_time = time.time()  # время окончания выполнения
ex_time_neigh_full = end_time - start_time  # вычисляем время выполнения

print(f"Время выполнения программы: {ex_time_neigh_full} секунд")
# Out:
# Время выполнения программы: 339.5071680545807 секунд
# CPU times: total: 42min 10s
# Wall time: 5min 39s

# %%
base_index = {k: v for k, v in enumerate(base.index.to_list())}

# %%
acc = 0
for target, el in zip(targets.values.tolist(), indices.tolist()):
    acc += int(target in [base_index[r] for r in el])

acc_neigh_full = 100 * acc / len(indices)
print(acc_neigh_full, "%")
# Out:
# 71.933 %

# %% [markdown]
# #### Validation

# %%
targets_valid = validation_answer['Expected']

# %%
# %%time
distances, indices = neigh.kneighbors(validation)
# Out:
# CPU times: total: 45min 18s
# Wall time: 6min 6s

# %%
acc = 0
for target, el in zip(targets_valid.values.tolist(), indices.tolist()):
    acc += int(target in [base_index[B] for B in el])

print(100 * acc / len(indices))
# Out:
# 71.816

# %% [markdown]
# ### Faiss full dataset

# %%
dim = base.shape[1] #how many partitions we’d like our index to have
nlist = 500 # количество кластеров 
quantizer = faiss.IndexFlatL2(dim) 
#quantiser = faiss.IndexFlatIP(dim)
index = faiss.IndexIVFFlat(quantizer, dim, nlist, faiss.METRIC_L2) #METRIC_INNER_PRODUCT

# %%
# %%time
#Запускаем обучение:
print(index.is_trained)   # False.
index.train(vectors)  # Train на нашем наборе векторов
 
# Обучение завершено, но векторов в индексе пока нет, так что добавляем их в индекс:
print(index.is_trained)  # True
print(index.ntotal)   # 0
index.add(vectors)
print(index.ntotal)   # 1000000
# Out:
# False
# True
# 0
# 2918139

# %%
start_time = time.time()  # время начала выполнения

index.nprobe = 40 #int(math.sqrt(base_mini.shape[0]))  # Проходим по топ-16 центроид для поиска top-n ближайших соседей
D, I = index.search(query, 5) 

end_time = time.time()  # время окончания выполнения
ex_time_IndexIVFFlat = end_time - start_time  # вычисляем время выполнения

print(f"Время выполнения программы: {ex_time_IndexIVFFlat} секунд")
# Out:
# Время выполнения программы: 197.86979699134827 секунд

# %%
base_index = {k: v for k, v in enumerate(base.index.to_list())}

# %%
acc = 0
for target, el in zip(targets.values.tolist(), I.tolist()):
    acc += int(target in [base_index[B] for B in el])

acc_IndexIVFFlat_L2 = 100 * acc / len(I)
print(acc_IndexIVFFlat_L2, "%")
# Out:
# 71.47 %

# %% [markdown]
# #### Validation

# %%
vectors = np.ascontiguousarray(base.values).astype('float32')
vectors
# Out:
# array([[-1.1592162 ,  0.6203504 , -0.51372266, ..., -0.0140507 ,
#          1.7814198 , -0.3123287 ],
#        [ 2.0757148 ,  1.0604233 , -0.652491  , ...,  0.05984761,
#          1.8537259 , -0.2810519 ],
#        [ 1.2854173 , -0.34334213,  0.39787757, ...,  0.04852086,
#         -0.7138468 ,  0.36562327],
#        ...,
#        [-0.43377605, -2.064035  , -0.6909693 , ...,  0.65973157,
#         -0.7138468 ,  1.2577736 ],
#        [-0.02446461,  0.16793925,  0.25220424, ...,  0.43807346,
#         -0.7138468 , -0.19157949],
#        [-0.6321802 ,  0.96488   , -0.17634064, ..., -1.0735649 ,
#         -0.7121896 ,  1.4986584 ]], dtype=float32)

# %%
query_valid = np.ascontiguousarray(validation.values).astype('float32')
query_valid
# Out:
# array([[ 1.1593095 , -0.9049013 ,  0.811955  , ..., -0.02012073,
#         -0.77784467, -1.6596744 ],
#        [ 1.3045019 ,  0.95090973,  0.03396855, ...,  0.36953282,
#          0.14243601,  0.54570097],
#        [ 0.88602704, -2.434901  ,  0.9552155 , ...,  1.2049444 ,
#          1.3110267 , -0.5551965 ],
#        ...,
#        [ 1.0849174 ,  1.1115147 ,  1.7404357 , ..., -0.83314174,
#          2.263597  ,  0.47211984],
#        [ 2.1242688 ,  0.7250045 ,  0.3365892 , ...,  1.60763   ,
#          1.6249286 , -0.3145498 ],
#        [ 1.8268185 , -0.25182068,  0.37760124, ...,  0.72920394,
#          0.46906516,  0.34907994]], dtype=float32)

# %%
targets_valid = validation_answer['Expected']

# %%
dim = base.shape[1] #how many partitions we’d like our index to have
nlist = 500 # количество кластеров 141
quantizer = faiss.IndexFlatL2(dim) 
#quantiser = faiss.IndexFlatIP(dim)
index = faiss.IndexIVFFlat(quantizer, dim, nlist, faiss.METRIC_L2) #METRIC_INNER_PRODUCT

# %%
index.train(vectors)
index.add(vectors)

# %%
# %%time
index.nprobe = 40  # Проходим по топ-40 центроид для поиска top-n ближайших соседей
D, I = index.search(query_valid, 5)
# Out:
# CPU times: total: 49min 43s
# Wall time: 3min 16s

# %%
base_index = {k: v for k, v in enumerate(base.index.to_list())}

# %%
acc = 0
for target, el in zip(targets_valid.values.tolist(), I.tolist()):
    acc += int(target in [base_index[B] for B in el])

print(100 * acc / len(I))
# Out:
# 71.415

# %%
# %%time
index.nprobe = 100  # Проходим по топ-100 центроид для поиска top-n ближайших соседей
D, I = index.search(query_valid, 5)
# Out:
# CPU times: total: 2h 1min 50s
# Wall time: 8min

# %%
base_index = {k: v for k, v in enumerate(base.index.to_list())}

# %%
acc = 0
for target, el in zip(targets_valid.values.tolist(), I.tolist()):
    acc += int(target in [base_index[B] for B in el])

print(100 * acc / len(I))
# Out:
# 71.628

# %% [markdown]
# ## Итоговый вывод

# %% [markdown]
# В нашем распоряжении были датасеты с полностью анонимизированными признаками. Необходимо было решить задачу матчинга: для каждого запроса из validation подобрать 5 наиболее близких объектов из base.
#
# В ходе проекта мы провели следующие этапы:
#
# * загрузка и ознакомление с данными
# * предобработка данных
# * выбор лучшей модели матчинга
# * получение предсказаний на валидационной выборке
# * итоговая оценка качества лучшей модели
#
# По итогам тестирования лучшие результаты точности показали модели NearestNeighbors и faiss с индексом IndexFlatL2. Однако NearestNeighbors существенно выигрывает по времени.
